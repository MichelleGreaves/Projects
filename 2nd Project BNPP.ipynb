# %% [markdown]
# Public Health Ageny Project

# %% [markdown]
# Introduction

# %%
#import libraries
import pandas as pd
from matplotlib import pyplot
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
from numpy import random
import seaborn as sns

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Michelle'

# %% [markdown]
# Data Analysis / Data Cleaning

# %%
#Read CSV
df = pd.read_csv("fr.openfoodfacts.org.csv", sep ='\t', nrows=20)

# %%
df.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1   4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2   4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4  16094  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# 0       1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
df = pd.read_csv("fr.openfoodfacts.org.csv", sep ='\t')
# Out:
# C:\Intel\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,35,36,37,38,39,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1   4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2   4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4  16094  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
df.tail()
# Out:
#                  code                                                url  \
# 320767  9948282780603  http://world-fr.openfoodfacts.org/produit/9948...
# 320768       99567453  http://world-fr.openfoodfacts.org/produit/9956...
# 320769  9970229501521  http://world-fr.openfoodfacts.org/produit/9970...
# 320770  9980282863788  http://world-fr.openfoodfacts.org/produit/9980...
# 320771   999990026839  http://world-fr.openfoodfacts.org/produit/9999...
#
#                            creator   created_t      created_datetime  \
# 320767  openfoodfacts-contributors  1490631299  2017-03-27T16:14:59Z
# 320768             usda-ndb-import  1489059076  2017-03-09T11:31:16Z
# 320769                      tomato  1422099377  2015-01-24T11:36:17Z
# 320770  openfoodfacts-contributors  1492340089  2017-04-16T10:54:49Z
# 320771             usda-ndb-import  1489072709  2017-03-09T15:18:29Z
#
#        last_modified_t last_modified_datetime  \
# 320767      1491244498   2017-04-03T18:34:58Z
# ...

# %%
df.isnull().sum()
# Out:
# code                           23
# url                            23
# creator                         2
# created_t                       3
# created_datetime                9
#                             ...
# carbon-footprint_100g      320504
# nutrition-score-fr_100g     99562
# nutrition-score-uk_100g     99562
# glycemic-index_100g        320772
# water-hardness_100g        320772
# Length: 162, dtype: int64

# %%
df
# Out:
#                  code                                                url  \
# 0                3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1                4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2                4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3               16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4               16094  http://world-fr.openfoodfacts.org/produit/0000...
# ...               ...                                                ...
# 320767  9948282780603  http://world-fr.openfoodfacts.org/produit/9948...
# 320768       99567453  http://world-fr.openfoodfacts.org/produit/9956...
# 320769  9970229501521  http://world-fr.openfoodfacts.org/produit/9970...
# 320770  9980282863788  http://world-fr.openfoodfacts.org/produit/9980...
# 320771   999990026839  http://world-fr.openfoodfacts.org/produit/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
#describe DF
df.describe()
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  248939.000000                248939.000000
# mean             NaN       1.936024                     0.019659
# std              NaN       2.502019                     0.140524
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      31.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            248939.000000
# mean                         NaN                                 0.055246
# std                          NaN                                 0.269207
# min                          NaN                                 0.000000
# ...

# %%
df.shape[0]
# Out:
# 320772

# %%
df.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'ph_100g', 'fruits-vegetables-nuts_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=162)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320772 entries, 0 to 320771
# Columns: 162 entries, code to water-hardness_100g
# dtypes: float64(106), object(56)
# memory usage: 396.5+ MB

# %%
df.dtypes
# Out:
# code                        object
# url                         object
# creator                     object
# created_t                   object
# created_datetime            object
#                             ...
# carbon-footprint_100g      float64
# nutrition-score-fr_100g    float64
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# Length: 162, dtype: object

# %%
#df.apply(pd.Series.value_counts)
# Out:
#                                                     code  url  creator  \
# -800.0                                               NaN  NaN      NaN
# -500.0                                               NaN  NaN      NaN
# -17.86                                               NaN  NaN      NaN
# -15.0                                                NaN  NaN      NaN
# -14.0                                                NaN  NaN      NaN
# ...                                                  ...  ...      ...
# 푹신푹신 말랑카우                                            NaN  NaN      NaN
# ﬁlet de porc(89%), bouillons(2.5%) (eau, os de ...   NaN  NaN      NaN
# ﬁlets de hareng fumés (_poisson_)(75%), huile d...   NaN  NaN      NaN
# Ｌｏｎｋａ牌花生杂果味软牛轧糖180克                                  NaN  NaN      NaN
# 🍺                                                    NaN  NaN      NaN
#
#                                                     created_t  \
# ...

# %%
#Describe data frame
print(df.describe())
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  248939.000000                248939.000000
# mean             NaN       1.936024                     0.019659
# std              NaN       2.502019                     0.140524
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      31.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            248939.000000
# mean                         NaN                                 0.055246
# std                          NaN                                 0.269207
# min                          NaN                                 0.000000
# ...

# %%
#Most common 
df['creator'].value_counts().idxmax()
# Out:
# 'usda-ndb-import'

# %%
#Most common location type
df['product_name'].value_counts().idxmax()
# Out:
# 'Ice Cream'

# %%
#Most common location type
df['created_datetime'].value_counts().idxmax()
# Out:
# '2017-03-09T10:37:09Z'

# %%
df.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1   4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2   4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4  16094  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
df['countries_fr']
# Out:
# 0             France
# 1         États-Unis
# 2         États-Unis
# 3         États-Unis
# 4         États-Unis
#              ...
# 320767      Roumanie
# 320768    États-Unis
# 320769         Chine
# 320770        France
# 320771    États-Unis
# Name: countries_fr, Length: 320772, dtype: object

# %%
#Showing the top 10 widest trees
df['countries_fr'].value_counts()
# Out:
# États-Unis                   172998
# France                        94392
# Suisse                        14953
# Allemagne                      7870
# Espagne                        5009
#                               ...
# États-Unis,en:Pays-bas            1
# Belgique,France,Italie            1
# France,Allemagne,Pays-Bas         1
# République centrafricaine         1
# France,Luxembourg,Suisse          1
# Name: countries_fr, Length: 722, dtype: int64

# %%
df[df['countries_fr'].isin(['États-Unis', 'France', 'Suisse', 'Espagne', 'Allemagne'])]
# Out:
#                  code                                                url  \
# 0                3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1                4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2                4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3               16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4               16094  http://world-fr.openfoodfacts.org/produit/0000...
# ...               ...                                                ...
# 320764           9918  http://world-fr.openfoodfacts.org/produit/9918...
# 320765  9935010000003  http://world-fr.openfoodfacts.org/produit/9935...
# 320768       99567453  http://world-fr.openfoodfacts.org/produit/9956...
# 320770  9980282863788  http://world-fr.openfoodfacts.org/produit/9980...
# 320771   999990026839  http://world-fr.openfoodfacts.org/produit/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df.sort_values('percent_missing', inplace=True)

# %%
missing_value_df
# Out:
#                                                                  column_name  \
# last_modified_t                                              last_modified_t
# last_modified_datetime                                last_modified_datetime
# creator                                                              creator
# created_t                                                          created_t
# created_datetime                                            created_datetime
# ...                                                                      ...
# ingredients_that_may_be_from_palm_oil  ingredients_that_may_be_from_palm_oil
# ingredients_from_palm_oil                          ingredients_from_palm_oil
# no_nutriments                                                  no_nutriments
# nervonic-acid_100g                                        nervonic-acid_100g
# water-hardness_100g                                      water-hardness_100g
#
# ...

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df
# Out:
#                                      column_name  percent_missing
# code                                        code         0.007170
# url                                          url         0.007170
# creator                                  creator         0.000623
# created_t                              created_t         0.000935
# created_datetime                created_datetime         0.002806
# ...                                          ...              ...
# carbon-footprint_100g      carbon-footprint_100g        99.916452
# nutrition-score-fr_100g  nutrition-score-fr_100g        31.038245
# nutrition-score-uk_100g  nutrition-score-uk_100g        31.038245
# glycemic-index_100g          glycemic-index_100g       100.000000
# water-hardness_100g          water-hardness_100g       100.000000
#
# [162 rows x 2 columns]

# %%
print (df.isnull().mean() * 100)
# Out:
# code                         0.007170
# url                          0.007170
# creator                      0.000623
# created_t                    0.000935
# created_datetime             0.002806
#                               ...
# carbon-footprint_100g       99.916452
# nutrition-score-fr_100g     31.038245
# nutrition-score-uk_100g     31.038245
# glycemic-index_100g        100.000000
# water-hardness_100g        100.000000
# Length: 162, dtype: float64

# %%
df2 = df.loc[:, df.isnull().mean() <= .5]
print (df2)
# Out:
#                  code                                                url  \
# 0                3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1                4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2                4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3               16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4               16094  http://world-fr.openfoodfacts.org/produit/0000...
# ...               ...                                                ...
# 320767  9948282780603  http://world-fr.openfoodfacts.org/produit/9948...
# 320768       99567453  http://world-fr.openfoodfacts.org/produit/9956...
# 320769  9970229501521  http://world-fr.openfoodfacts.org/produit/9970...
# 320770  9980282863788  http://world-fr.openfoodfacts.org/produit/9980...
# 320771   999990026839  http://world-fr.openfoodfacts.org/produit/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
df2.corr()
# Out:
#                                          additives_n  \
# additives_n                                 1.000000
# ingredients_from_palm_oil_n                 0.119898
# ingredients_that_may_be_from_palm_oil_n     0.285766
# energy_100g                                -0.002743
# fat_100g                                   -0.120568
# saturated-fat_100g                         -0.052829
# carbohydrates_100g                          0.154875
# sugars_100g                                 0.136117
# fiber_100g                                 -0.050628
# proteins_100g                              -0.103616
# salt_100g                                  -0.000947
# sodium_100g                                -0.000947
# nutrition-score-fr_100g                     0.167214
# nutrition-score-uk_100g                     0.163123
#
#                                          ingredients_from_palm_oil_n  \
# additives_n                                                 0.119898
# ...

# %% [markdown]
# Data Vizualization of correlation of a heatmap

# %%
corr = df2.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
df2.count()
# Out:
# code                                       320749
# url                                        320749
# creator                                    320770
# created_t                                  320769
# created_datetime                           320763
# last_modified_t                            320772
# last_modified_datetime                     320772
# product_name                               303010
# brands                                     292360
# brands_tags                                292352
# countries                                  320492
# countries_tags                             320492
# countries_fr                               320492
# ingredients_text                           248962
# serving_size                               211331
# additives_n                                248939
# additives                                  248905
# ingredients_from_palm_oil_n                248939
# ingredients_that_may_be_from_palm_oil_n    248939
# ...

# %%
df2.max()
# Out:
# last_modified_datetime                     en:france,en:switzerland
# additives_n                                                      31
# ingredients_from_palm_oil_n                                       2
# ingredients_that_may_be_from_palm_oil_n                           6
# energy_100g                                             3.25137e+06
# fat_100g                                                     714.29
# saturated-fat_100g                                              550
# carbohydrates_100g                                          2916.67
# sugars_100g                                                    3520
# fiber_100g                                                     5380
# proteins_100g                                                   430
# salt_100g                                                   64312.8
# sodium_100g                                                   25320
# nutrition-score-fr_100g                                          40
# ...

# %%
df2.min()
# Out:
# last_modified_datetime                     2012-03-21T22:15:32Z
# additives_n                                                   0
# ingredients_from_palm_oil_n                                   0
# ingredients_that_may_be_from_palm_oil_n                       0
# energy_100g                                                   0
# fat_100g                                                      0
# saturated-fat_100g                                            0
# carbohydrates_100g                                            0
# sugars_100g                                              -17.86
# fiber_100g                                                 -6.7
# proteins_100g                                              -800
# salt_100g                                                     0
# sodium_100g                                                   0
# nutrition-score-fr_100g                                     -15
# nutrition-score-uk_100g                                     -15
# ...

# %%
df2.median()
# Out:
# code                                       8.053852e+11
# additives_n                                1.000000e+00
# ingredients_from_palm_oil_n                0.000000e+00
# ingredients_that_may_be_from_palm_oil_n    0.000000e+00
# energy_100g                                1.100000e+03
# fat_100g                                   5.000000e+00
# saturated-fat_100g                         1.790000e+00
# carbohydrates_100g                         2.060000e+01
# sugars_100g                                5.710000e+00
# fiber_100g                                 1.500000e+00
# proteins_100g                              4.760000e+00
# salt_100g                                  5.816600e-01
# sodium_100g                                2.290000e-01
# nutrition-score-fr_100g                    1.000000e+01
# nutrition-score-uk_100g                    9.000000e+00
# dtype: float64

# %%
df2.std()
# Out:
# additives_n                                   2.502019
# ingredients_from_palm_oil_n                   0.140524
# ingredients_that_may_be_from_palm_oil_n       0.269207
# energy_100g                                6447.154093
# fat_100g                                     17.578747
# saturated-fat_100g                            8.014238
# carbohydrates_100g                           29.731719
# sugars_100g                                  22.327284
# fiber_100g                                   12.867578
# proteins_100g                                 8.409054
# salt_100g                                   128.269454
# sodium_100g                                  50.504428
# nutrition-score-fr_100g                       9.055903
# nutrition-score-uk_100g                       9.183589
# dtype: float64

# %%
df2.isnull().sum()
# Out:
# code                                           23
# url                                            23
# creator                                         2
# created_t                                       3
# created_datetime                                9
# last_modified_t                                 0
# last_modified_datetime                          0
# product_name                                17762
# brands                                      28412
# brands_tags                                 28420
# countries                                     280
# countries_tags                                280
# countries_fr                                  280
# ingredients_text                            71810
# serving_size                               109441
# additives_n                                 71833
# additives                                   71867
# ingredients_from_palm_oil_n                 71833
# ingredients_that_may_be_from_palm_oil_n     71833
# ...

# %%
#Dealing with NAs 
def fillna(brands):
    brands.fillna(brands.value_counts().index[0], inplace=True)
    return brands
df2=df2.apply(lambda brands:fillna(brands))

# %%
#Dealing with NAs 
def fillna(url):
    url.fillna(url.value_counts().index[0], inplace=True)
    return url
df2=df2.apply(lambda url:fillna(url))

# %%
#Dealing with NAs 
def fillna(creator):
    creator.fillna(creator.value_counts().index[0], inplace=True)
    return creator
df2=df2.apply(lambda creator:fillna(creator))

# %%
#Dealing with NAs 
def fillna(product_name):
    product_name.fillna(product_name.value_counts().index[0], inplace=True)
    return product_name
df2=df2.apply(lambda product_name:fillna(product_name))

# %%
#Dealing with NAs 
def fillna(last_modified_date):
    last_modified_date.fillna(last_modified_date.value_counts().index[0], inplace=True)
    return last_modified_date
df2=df2.apply(lambda last_modified_date:fillna(last_modified_date))

# %%
#Dealing with NAs 
def fillna(last_modified_t):
    last_modified_t.fillna(last_modified_t.value_counts().index[0], inplace=True)
    return last_modified_t
df2=df2.apply(lambda last_modified_t:fillna(last_modified_t))

# %%
#Dealing with NAs 
def fillna(created_datetime):
    created_datetime.fillna(created_datetime.value_counts().index[0], inplace=True)
    return created_datetime
df2=df2.apply(lambda created_datetime:fillna(created_datetime))

# %%
#Dealing with NAs 
def fillna(created_t):
    created_t.fillna(created_t.value_counts().index[0], inplace=True)
    return created_t
df2=df2.apply(lambda created_t:fillna(created_t))

# %%
df2.isnull().sum()
# Out:
# code                                       0
# url                                        0
# creator                                    0
# created_t                                  0
# created_datetime                           0
# last_modified_t                            0
# last_modified_datetime                     0
# product_name                               0
# brands                                     0
# brands_tags                                0
# countries                                  0
# countries_tags                             0
# countries_fr                               0
# ingredients_text                           0
# serving_size                               0
# additives_n                                0
# additives                                  0
# ingredients_from_palm_oil_n                0
# ingredients_that_may_be_from_palm_oil_n    0
# nutrition_grade_fr                         0
# states                                     0
# ...

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320772 entries, 0 to 320771
# Data columns (total 34 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   code                                     320772 non-null  object
#  1   url                                      320772 non-null  object
#  2   creator                                  320772 non-null  object
#  3   created_t                                320772 non-null  object
#  4   created_datetime                         320772 non-null  object
#  5   last_modified_t                          320772 non-null  object
#  6   last_modified_datetime                   320772 non-null  object
#  7   product_name                             320772 non-null  object
#  8   brands                                   320772 non-null  object
#  9   brands_tags                              320772 non-null  object
# ...

# %%
df2.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-fr.openfoodfacts.org/produit/0000...
# 1   4530  http://world-fr.openfoodfacts.org/produit/0000...
# 2   4559  http://world-fr.openfoodfacts.org/produit/0000...
# 3  16087  http://world-fr.openfoodfacts.org/produit/0000...
# 4  16094  http://world-fr.openfoodfacts.org/produit/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# ...

# %%
#Data vizulations of data
# %matplotlib inline
import matplotlib.pyplot as plt
df2.hist(bins=50, figsize=(11,8))
save_fig("histograms")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-52767653efbd> in <module>
#       3 import matplotlib.pyplot as plt
#       4 df2.hist(bins=50, figsize=(11,8))
# ----> 5 save_fig("histograms")
#       6 plt.show()
#
# NameError: name 'save_fig' is not defined

# %%
df2['product_name'].groupby(df2['product_name']).value_counts()
# Out:
# product_name                                       product_name
#                                                                                                         3
#   Bridelight 3% Les carrés fondants goût Emmental    Bridelight 3% Les carrés fondants goût Emmental    1
#   Organic Soymilk Unsweetened                        Organic Soymilk Unsweetened                        1
#   Président                                          Président                                          1
#   bière blonde pur malt                              bière blonde pur malt                              1
#                                                                                                        ..
# 통깨                                                 통깨                                                   1
# 폰즈소스 - Shabu Shabu Ponzu                           폰즈소스 - Shabu Shabu Ponzu                             1
# ...

# %%
#from sklearn.preprocessing import StandardScaler
#df3 = StandardScaler().fit_transform(df3)
#df3[:5]

# %%
#df2 = np.random.RandomState(1)
#X = np.dot(df2.rand(2, 2), df2.randn(2, 200)).T
#plt.scatter(X[:, 0], X[:, 1])
#plt.axis('equal');

# %%
#from sklearn.decomposition import PCA
#pca = PCA(n_components=2)
#pca.fit(X)

# %%
#print(pca.components_)

# %%
#print(pca.explained_variance_)

# %%
#def draw_vector(v0, v1, ax=None):
 #   ax = ax or plt.gca()
    #arrowprops=dict(arrowstyle='->',
       #             linewidth=2,
        #            shrinkA=0, shrinkB=0)
    #ax.annotate('', v1, v0, arrowprops=arrowprops)

# plot data
#plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
#for length, vector in zip(pca.explained_variance_, pca.components_):
 #   v = vector * 3 * np.sqrt(length)
  #  draw_vector(pca.mean_, pca.mean_ + v)
#plt.axis('equal');

# %%
#pca = PCA(n_components=1)
#pca.fit(X)
#X_pca = pca.transform(X)
#print("original shape:   ", X.shape)
#print("transformed shape:", X_pca.shape)

# %%
#X_new = pca.inverse_transform(X_pca)
#plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
#plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.8)
#plt.axis('equal');

# %%
#from sklearn.datasets import load_digits
#digits = load_digits()
#digits.data.shape

# %%
#By arrondissement sorting by top 10 tree type
df2.sort_values(['nutrition-score-fr_100g', 'product_name']).groupby(['nutrition-score-fr_100g', 'product_name']).head(10)
#Kmeans
# Out:
#                  code                                                url  \
# 229885  3380390204408  http://world-fr.openfoodfacts.org/produit/3380...
# 199759  3222471016886  http://world-fr.openfoodfacts.org/produit/3222...
# 311235  8480000610232  http://world-fr.openfoodfacts.org/produit/8480...
# 279242  5411788045094  http://world-fr.openfoodfacts.org/produit/5411...
# 218804  3270160103713  http://world-fr.openfoodfacts.org/produit/3270...
# ...               ...                                                ...
# 55961     43000054048  http://world-fr.openfoodfacts.org/produit/0043...
# 55852     43000013090  http://world-fr.openfoodfacts.org/produit/0043...
# 177065       20009373  http://world-fr.openfoodfacts.org/produit/2000...
# 55878     43000032893  http://world-fr.openfoodfacts.org/produit/0043...
# 55851     43000013083  http://world-fr.openfoodfacts.org/produit/0043...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
#By arrondissement sorting by top 10 variety
df2.sort_values(['nutrition-score-uk_100g', 'brands']).groupby(['nutrition-score-uk_100g', 'brands']).head(10)
# Out:
#                  code                                                url  \
# 229885  3380390204408  http://world-fr.openfoodfacts.org/produit/3380...
# 199759  3222471016886  http://world-fr.openfoodfacts.org/produit/3222...
# 279242  5411788045094  http://world-fr.openfoodfacts.org/produit/5411...
# 218804  3270160103713  http://world-fr.openfoodfacts.org/produit/3270...
# 311235  8480000610232  http://world-fr.openfoodfacts.org/produit/8480...
# ...               ...                                                ...
# 55945     43000050316  http://world-fr.openfoodfacts.org/produit/0043...
# 55961     43000054048  http://world-fr.openfoodfacts.org/produit/0043...
# 55851     43000013083  http://world-fr.openfoodfacts.org/produit/0043...
# 55852     43000013090  http://world-fr.openfoodfacts.org/produit/0043...
# 55878     43000032893  http://world-fr.openfoodfacts.org/produit/0043...
#
#                 creator   created_t      created_datetime last_modified_t  \
# ...

# %%
#By arrondissement sorting by top 10 variety
df2.sort_values(['product_name']).head(10)
# Out:
#                  code                                                url  \
# 315118  8714789999784  http://world-fr.openfoodfacts.org/produit/8714...
# 294518  7613269752103  http://world-fr.openfoodfacts.org/produit/7613...
# 625             52337  http://world-fr.openfoodfacts.org/produit/0005...
# 201989  3228023020073  http://world-fr.openfoodfacts.org/produit/3228...
# 109917    99482417031  http://world-fr.openfoodfacts.org/produit/0099...
# 201986  3228022990193  http://world-fr.openfoodfacts.org/produit/3228...
# 220571  3272460122364  http://world-fr.openfoodfacts.org/produit/3272...
# 201009  3222474224738  http://world-fr.openfoodfacts.org/produit/3222...
# 300929  8000300137965  http://world-fr.openfoodfacts.org/produit/8000...
# 210545  3256222643496  http://world-fr.openfoodfacts.org/produit/3256...
#
#                            creator   created_t      created_datetime  \
# 315118  openfoodfacts-contributors  1463765792  2016-05-20T17:36:32Z
# ...

# %%
rows = df.shape
rows = rows[0]
print(rows)
test = df
# Out:
# 320772

# %%
test = df2
def stack_values(col):
    counts = test[col].value_counts()
    counts = counts.to_frame(name='counts')
    counts['percentage'] = counts['counts']/rows

    top_10 = round(sum(counts[0:10]['percentage']),2)*100
    print("The 10 main", col,"account for", top_10,"% of all contributions")

def top_ten(col):
    counts = test[col].value_counts()
    counts = counts.to_frame(name='counts')
    counts['percentage'] = counts['counts']/rows

    top_10 = round(sum(counts[0:10]['percentage']),2)*100
    print("The 10 main", col,"account for", top_10,"% of all contributions \n")
    print(counts.head(10))
    
#print(stack_values('creator'))
print(top_ten('creator'))
# Out:
# The 10 main creator account for 84.0 % of all contributions
#
#                             counts  percentage
# usda-ndb-import             169870    0.529566
# openfoodfacts-contributors   40117    0.125064
# kiliweb                      13891    0.043305
# date-limite-app              11918    0.037154
# openfood-ch-import           11478    0.035782
# tacite                        7214    0.022489
# sebleouf                      5864    0.018281
# tacinte                       4398    0.013711
# javichu                       2768    0.008629
# stephane                      2691    0.008389
# None

# %%
simple_checks = ['countries', 'brands', 'product_name', 'countries_fr']

# States are not US states. It refers to the state of the entry, e.g. 'To be completed.
# Additives need to be checked
# I don't yet understand palm oil in anyway
complex_checks = ['states', 'additives', 'ingredients_that_may_be_from_palm_oil_n']

# %%
import matplotlib.style as style
style.use('fivethirtyeight')

fig = plt.figure(figsize=(16,20))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
ax_list = [ax1,ax2,ax3,ax4]
plt.subplots_adjust(hspace=0.4, wspace=0.5)

axes_count = 0
for c in simple_checks:
    counts = df2[c].value_counts()
    counts = counts.to_frame(name='counts').reset_index()
    counts['percentage'] = counts['counts']/rows
    counts.drop(['counts'], axis = 1, inplace = True)
    counts_ten = counts[0:10]
       
    g = sns.barplot(x='index', y='percentage', data=counts_ten, ax=ax_list[axes_count])
    g.set_xticklabels(rotation = 45, labels=counts['index'])
    
    sns.despine()
    ax_list[axes_count].set_title(c, fontsize=16)
    axes_count += 1

plt.show()

# %%
print("What brands are in the France? \n")
France = df2[df2['countries']== "France"]
print(df2['brands'].value_counts().head(10))
What brands are in the France?
# Out:
# What brands are in the France?
#
# Carrefour       31390
# Auchan           2340
# U                2050
# Meijer           1995
# Leader Price     1700
# Kroger           1660
# Casino           1608
# Ahold            1370
# Spartan          1341
# Roundy's         1299
# Name: brands, dtype: int64

# %%
fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(121)

fr_values = France['brands'].value_counts()
fr_values[0:10].plot(kind='bar', ax=ax1, title="What categories are most common in FR?")
plt.show()

# %%
add_df = df2[df2['additives'].notnull()]
add_countries = add_df['countries'].value_counts()
print(add_countries[0:10])
add_creators = add_df['creator'].value_counts()
print("\n Creators of Additive entries")
print(add_creators[0:10])
# Out:
# US                170208
# France             77292
# en:FR              16979
# Suisse             12314
# Deutschland         6161
# España              3688
# United Kingdom      3247
# United States       2248
# en:CH               2150
# en:BE               1538
# Name: countries, dtype: int64
#
#  Creators of Additive entries
# usda-ndb-import               169870
# openfoodfacts-contributors     40117
# kiliweb                        13891
# date-limite-app                11918
# openfood-ch-import             11478
# tacite                          7214
# sebleouf                        5864
# tacinte                         4398
# javichu                         2768
# stephane                        2691
# Name: creator, dtype: int64

# %%
data=pd.DataFrame(df2, columns = ['brands','proteins_100g'])
data=(data)
data.describe()
# Out:
#        proteins_100g
# count  320772.000000
# mean        5.733644
# std         8.061912
# min      -800.000000
# 25%         0.000000
# 50%         3.000000
# 75%         8.240000
# max       430.000000

# %%
df2.boxplot(column=['energy_100g', 'nutrition-score-fr_100g', 'fat_100g', 'proteins_100g'], grid=False, figsize=(20,10), showfliers=False)

# %%
df2.boxplot(column=['carbohydrates_100g', 'additives_n', 'saturated-fat_100g', 'sugars_100g'], grid=False,figsize=(20,10),showfliers=False)

# %%
# load packages
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns F and P-value
fvalue, pvalue = stats.f_oneway(df2['carbohydrates_100g'], df2['additives_n'], df2['saturated-fat_100g'], df2['sugars_100g'])
print(fvalue, pvalue)


# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols
# reshape the d dataframe suitable for statsmodels package 
d_melt = pd.melt(df2.reset_index(), id_vars=['index'], value_vars=['carbohydrates_100g', 'additives_n', 'saturated-fat_100g', 'sugars_100g'])
# replace column names
d_melt.columns = ['index', 'treatments', 'value']
# Ordinary Least Squares (OLS) model
model = ols('value ~ C(treatments)', data=d_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
# 102715.90512973018 0.0
#                      sum_sq         df             F  PR(>F)
# C(treatments)  1.034607e+08        3.0  102715.90513     0.0
# Residual       4.307957e+08  1283084.0           NaN     NaN

# %%
from bioinfokit.analys import stat
res = stat()
res.tukey_hsd(df=d_melt, res_var='value', xfac_var='treatments', anova_model='value ~ C(treatments)')
res.tukey_summary
# Out:
#                group1              group2       Diff      Lower      Upper  \
# 0  carbohydrates_100g         additives_n  22.853880  22.736339  22.971422
# 1  carbohydrates_100g  saturated-fat_100g  20.685223  20.567681  20.802765
# 2  carbohydrates_100g         sugars_100g  12.134624  12.017082  12.252166
# 3         additives_n  saturated-fat_100g   2.168657   2.051115   2.286199
# 4         additives_n         sugars_100g  10.719257  10.601715  10.836798
# 5  saturated-fat_100g         sugars_100g   8.550599   8.433058   8.668141
#
#       q-value  p-value
# 0  706.398948    0.001
# 1  639.367131    0.001
# 2  375.073525    0.001
# 3   67.031816    0.001
# 4  331.325423    0.001
# 5  264.293607    0.001

# %%
conda install -c bioconda bioinfokit
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Intel\anaconda
#
#   added / updated specs:
#     - bioinfokit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bioinfokit-1.0.4           |     pyh3252c3a_0          55 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:          55 KB
#
# The following packages will be UPDATED:
#
#   bioinfokit                             1.0.2-pyh3252c3a_0 --> 1.0.4-pyh3252c3a_0
#
#
#
# ...
#
# bioinfokit-1.0.4     | 55 KB     |            |   0%
# bioinfokit-1.0.4     | 55 KB     | ##8        |  29%
# bioinfokit-1.0.4     | 55 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# ...

# %%
conda install -c conda-forge/label/gcc7 matplotlib-venn
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c primer adjusttext
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge adjusttext
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge/label/gcc7 tabulate
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge/label/gcc7 textwrap3
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# load packages
import scipy.stats as stats
w, pvalue = stats.shapiro(model.resid)
print(w, pvalue)
# Out:
# 0.7893252968788147 0.0
# C:\Intel\anaconda\lib\site-packages\scipy\stats\morestats.py:1676: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
# load packages
import scipy.stats as stats
w, pvalue = stats.bartlett(df2['energy_100g'], df2['nutrition-score-fr_100g'], df2['fat_100g'], df2['proteins_100g'])
print(w, pvalue)
# Out:
# 10399378.986543726 0.0

# %% [markdown]
# PCA

# %%
df2[['carbohydrates_100g']].plot.hist(bins = 100, title = 'Carbs')

# %%
df2.plot.scatter(x = 'carbohydrates_100g', y = 'energy_100g',
                  color = 'sandybrown', title = 'UnitPrice vs UnitDiscount')

# %%
df2.iloc[:10].plot.bar(x = 'brands', y = 'energy_100g', 
                                 color = 'skyblue', 
                                 title = 'Top 10 Sold Products By energy')

# %%
df2.iloc[:10].plot.bar(x = 'brands', y = 'saturated-fat_100g', 
                                 color = 'skyblue', 
                                 title = 'Top 10 Sold Products By energy')
